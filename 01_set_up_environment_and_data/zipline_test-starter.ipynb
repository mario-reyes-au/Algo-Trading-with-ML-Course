# %% [markdown]
# # Zipline Installation: Bundle Ingest & Algorithm Test

# %% [markdown]
# ## Imports and Settings

# %% [markdown]
# We don't need much here since the imports all take place in the cell where we formulate the algorithm.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# import warnings
# warnings.simplefilter(action='error', category=FutureWarning)

# %%
import os
from dotenv import load_dotenv, find_dotenv
import quandl

# %%
# %matplotlib inline

# %% [markdown]
# ## Load Zipline extension

# %%
# %load_ext zipline

# %% [markdown]
# ## Ingest Data

# %%
_ = load_dotenv(find_dotenv()) # read local .env file

QUANDL_API_KEY  = os.environ['QUANDL_API_KEY']
quandl.ApiConfig.api_key = QUANDL_API_KEY

# %%
# ! zipline ingest -b quandl

# %%
! zipline bundles
# Out:
# csvdir <no ingestions>
# quandl 2024-02-03 08:10:13.581101
# quandl 2024-02-03 08:08:25.246952
# quandl 2024-02-03 08:01:52.035707
# quandl 2024-02-03 07:59:49.699265
# quantopian-quandl <no ingestions>
# C:\Users\mario\miniforge3\envs\ATwML\lib\site-packages\exchange_calendars\exchange_calendar.py:2345: FutureWarning: 'T' is deprecated and will be removed in a future version. Please use 'min' instead of 'T'.
#   align: pd.Timedelta | str = pd.Timedelta(1, "T"),

# %% [markdown]
# ## Run a simple test algorithm

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 -o dma.pickle --no-benchmark
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2017-12-26 21:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2017-12-27 21:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2017-12-28 21:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2017-12-29 21:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
#
#                            shorts_count transactions  ... excess_return  \
# 2014-01-02 21:00:00+00:00             0           []  ...           0.0
# 2014-01-03 21:00:00+00:00             0           []  ...           0.0
# 2014-01-06 21:00:00+00:00             0           []  ...           0.0
# 2014-01-07 21:00:00+00:00             0           []  ...           0.0
# 2014-01-08 21:00:00+00:00             0           []  ...           0.0
# ...                                 ...          ...  ...           ...
# 2017-12-22 21:00:00+00:00             0           []  ...           0.0
# 2017-12-26 21:00:00+00:00             0           []  ...           0.0
# 2017-12-27 21:00:00+00:00             0           []  ...           0.0
# 2017-12-28 21:00:00+00:00             0           []  ...           0.0
# 2017-12-29 21:00:00+00:00             0           []  ...           0.0
#
#                            max_leverage  max_drawdown   sortino    sharpe  \
# 2014-01-02 21:00:00+00:00      0.000000      0.000000       NaN       NaN
# 2014-01-03 21:00:00+00:00      0.000000      0.000000       NaN       NaN
# 2014-01-06 21:00:00+00:00      0.000000      0.000000       NaN       NaN
# 2014-01-07 21:00:00+00:00      0.000000      0.000000       NaN       NaN
# 2014-01-08 21:00:00+00:00      0.000000      0.000000       NaN       NaN
# ...                                 ...           ...       ...       ...
# 2017-12-22 21:00:00+00:00      0.001763     -0.000295  1.012820  0.687600
# 2017-12-26 21:00:00+00:00      0.001763     -0.000295  0.913225  0.624704
# 2017-12-27 21:00:00+00:00      0.001763     -0.000295  0.913342  0.624784
# 2017-12-28 21:00:00+00:00      0.001763     -0.000295  0.922021  0.630682
# 2017-12-29 21:00:00+00:00      0.001763     -0.000295  0.884195  0.605565
#
#                            alpha  beta    AAPL  short_mavg   long_mavg
# 2014-01-02 21:00:00+00:00   None  None     NaN         NaN         NaN
# 2014-01-03 21:00:00+00:00   None  None     NaN         NaN         NaN
# 2014-01-06 21:00:00+00:00   None  None     NaN         NaN         NaN
# 2014-01-07 21:00:00+00:00   None  None     NaN         NaN         NaN
# 2014-01-08 21:00:00+00:00   None  None     NaN         NaN         NaN
# ...                          ...   ...     ...         ...         ...
# 2017-12-22 21:00:00+00:00   None  None  175.01  163.442190  142.891860
# 2017-12-26 21:00:00+00:00   None  None  170.57  163.598280  143.075387
# 2017-12-27 21:00:00+00:00   None  None  170.60  163.746503  143.259273
# 2017-12-28 21:00:00+00:00   None  None  171.08  163.899520  143.445907
# 2017-12-29 21:00:00+00:00   None  None  169.23  163.997280  143.626570
#
# [1007 rows x 40 columns]

# %%
import pandas as pd
_ = pd.read_pickle('dma.pickle') # read in perf DataFrame
figsize(12, 12)
import matplotlib.pyplot as plt

ax1 = plt.subplot(211)
_.portfolio_value.plot(ax=ax1)
ax1.set_ylabel('Portfolio Value')
ax2 = plt.subplot(212, sharex=ax1)
_.AAPL.plot(ax=ax2)
ax2.set_ylabel('AAPL Stock Price')
# Out:
# Text(0, 0.5, 'AAPL Stock Price')

# %%
_.loc[[t != [] for t in _.transactions]]
# Out:
#                                         period_open              period_close  \
# 2015-03-13 20:00:00+00:00 2015-03-13 13:31:00+00:00 2015-03-13 20:00:00+00:00
# 2015-11-19 21:00:00+00:00 2015-11-19 14:31:00+00:00 2015-11-19 21:00:00+00:00
# 2016-10-24 20:00:00+00:00 2016-10-24 13:31:00+00:00 2016-10-24 20:00:00+00:00
#
#                            ending_exposure  short_value       returns  \
# 2015-03-13 20:00:00+00:00          12359.0          0.0 -6.279500e-07
# 2015-11-19 21:00:00+00:00              0.0          0.0  1.429701e-05
# 2016-10-24 20:00:00+00:00          11765.0          0.0 -5.982795e-07
#
#                            starting_exposure  long_value  \
# 2015-03-13 20:00:00+00:00                0.0     12359.0
# 2015-11-19 21:00:00+00:00            11729.0         0.0
# 2016-10-24 20:00:00+00:00                0.0     11765.0
#
#                                                                    positions  \
# 2015-03-13 20:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
# 2015-11-19 21:00:00+00:00                                                 []
# 2016-10-24 20:00:00+00:00  [{'sid': Equity(8 [AAPL]), 'amount': 100, 'cos...
#
#                            shorts_count  \
# 2015-03-13 20:00:00+00:00             0
# 2015-11-19 21:00:00+00:00             0
# 2016-10-24 20:00:00+00:00             0
#
#                                                                 transactions  \
# 2015-03-13 20:00:00+00:00  [{'amount': 100, 'dt': 2015-03-13 20:00:00+00:...
# 2015-11-19 21:00:00+00:00  [{'amount': -100, 'dt': 2015-11-19 21:00:00+00...
# 2016-10-24 20:00:00+00:00  [{'amount': 100, 'dt': 2016-10-24 20:00:00+00:...
#
#                            ... excess_return  max_leverage  max_drawdown  \
# 2015-03-13 20:00:00+00:00  ...           0.0      0.001236 -6.279500e-07
# 2015-11-19 21:00:00+00:00  ...           0.0      0.001326 -2.952734e-04
# 2016-10-24 20:00:00+00:00  ...           0.0      0.001326 -2.952734e-04
#
#                             sortino    sharpe  alpha  beta    AAPL  \
# 2015-03-13 20:00:00+00:00 -0.914991 -0.914991   None  None  123.59
# 2015-11-19 21:00:00+00:00 -0.186764 -0.137033   None  None  118.78
# 2016-10-24 20:00:00+00:00 -0.154885 -0.113681   None  None  117.65
#
#                            short_mavg   long_mavg
# 2015-03-13 20:00:00+00:00   114.94520   95.799590
# 2015-11-19 21:00:00+00:00   115.96044  116.193067
# 2016-10-24 20:00:00+00:00   105.36488  105.031677
#
# [3 rows x 40 columns]
